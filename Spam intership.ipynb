# %% [markdown]
# # Spam Detection

# %%
import numpy as np
import pandas as pd
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import nltk

# %%
s=pd.read_csv(r"F:\Dataset\spam.csv",encoding='cp1252')
s.shape
# Out:
# (6776, 5)

# %%
s.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
s.v2.value_counts()
# Out:
# Sorry, I'll call later                                                                                                                                                                     38
# I cant pick the phone right now. Pls send a message                                                                                                                                        14
# Ok...                                                                                                                                                                                      10
# As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune                            9
# As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.                                7
#                                                                                                                                                                                            ..
# Hello. Damn this christmas thing. I think i have decided to keep this mp3 that doesnt work.                                                                                                 1
# You have 1 new message. Please call 08718738034.                                                                                                                                            1
# HI DARLIN IM MISSIN U HOPE YOU ARE HAVING A GOOD TIME. WHEN ARE U BACK AND WHAT TIME IF U CAN GIVE ME A CALL AT HOME. JESS XX                                                               1
# <Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert. You have 4 messages. You have 21 matches. Please call back on 09056242159 to retrieve your messages and matches     1
# Rofl. Its true to its name                                                                                                                                                                  1
# Name: v2, Length: 5165, dtype: int64

# %%
msg=s.iloc[:,[0,1]]
msg
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 6771  spam  This is the 2nd time we have tried 2 contact u...
# 6772   ham              Will Ì_ b going to esplanade fr home?
# 6773   ham  Pity, * was in mood for that. So...any other s...
# 6774   ham  The guy did some bitching but I acted like i'd...
# 6775   ham                         Rofl. Its true to its name
#
# [6776 rows x 2 columns]

# %%
msg.describe()
# Out:
#           v1                      v2
# count   6776                    6776
# unique     2                    5165
# top      ham  Sorry, I'll call later
# freq    5854                      38

# %%
msg.rename(columns={"v1":"label","v2":"message"},inplace=True)

# %%
msg
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 6771  spam  This is the 2nd time we have tried 2 contact u...
# 6772   ham              Will Ì_ b going to esplanade fr home?
# 6773   ham  Pity, * was in mood for that. So...any other s...
# 6774   ham  The guy did some bitching but I acted like i'd...
# 6775   ham                         Rofl. Its true to its name
#
# [6776 rows x 2 columns]

# %%
msg.label.value_counts()
# Out:
# ham     5854
# spam     922
# Name: label, dtype: int64

# %%
le=msg.message.apply(len)
le
# Out:
# 0       111
# 1        29
# 2       155
# 3        49
# 4        61
#        ...
# 6771    161
# 6772     37
# 6773     57
# 6774    125
# 6775     26
# Name: message, Length: 6776, dtype: int64

# %%
msg=pd.concat([msg,le],axis=1)
msg
# Out:
#      label                                            message  message
# 0      ham  Go until jurong point, crazy.. Available only ...      111
# 1      ham                      Ok lar... Joking wif u oni...       29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...      155
# 3      ham  U dun say so early hor... U c already then say...       49
# 4      ham  Nah I don't think he goes to usf, he lives aro...       61
# ...    ...                                                ...      ...
# 6771  spam  This is the 2nd time we have tried 2 contact u...      161
# 6772   ham              Will Ì_ b going to esplanade fr home?       37
# 6773   ham  Pity, * was in mood for that. So...any other s...       57
# 6774   ham  The guy did some bitching but I acted like i'd...      125
# 6775   ham                         Rofl. Its true to its name       26
#
# [6776 rows x 3 columns]

# %%
msg.columns.values[2]="length"

# %%
msg
# Out:
#      label                                            message  length
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# ...    ...                                                ...     ...
# 6771  spam  This is the 2nd time we have tried 2 contact u...     161
# 6772   ham              Will Ì_ b going to esplanade fr home?      37
# 6773   ham  Pity, * was in mood for that. So...any other s...      57
# 6774   ham  The guy did some bitching but I acted like i'd...     125
# 6775   ham                         Rofl. Its true to its name      26
#
# [6776 rows x 3 columns]

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#example on string punctuation
abc="i want to? rmove !! all the ...punctuation marks $ from %% "
abc_refined=[i for i in abc if i not in string.punctuation]
abc_refined
# Out:
# ['i',
#  ' ',
#  'w',
#  'a',
#  'n',
#  't',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'r',
#  'm',
#  'o',
#  'v',
#  'e',
#  ' ',
#  ' ',
#  'a',
#  'l',
#  'l',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'p',
#  'u',
#  'n',
#  'c',
#  't',
#  'u',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  'm',
#  'a',
#  'r',
#  'k',
#  's',
#  ' ',
#  ' ',
#  'f',
#  'r',
#  'o',
#  'm',
#  ' ',
#  ' ']

# %%
abc_refined="".join(abc_refined)
abc_refined
# Out:
# 'i want to rmove  all the punctuation marks  from  '

# %%
aa=abc_refined.split()
aa
# Out:
# ['i', 'want', 'to', 'rmove', 'all', 'the', 'punctuation', 'marks', 'from']

# %%
def text_process(mess):
    """
    1.remove the punctuation
    2.remove stopwords
    3.return the list of clean textwords
    """
    nopunc=[char for char in mess if char not in string.punctuation]
    nopunc="".join(nopunc)
    return[word for word in nopunc.split()if word not in stopwords.words("english")]

# %%
from wordcloud import WordCloud

# %%
cloud=WordCloud().generate(str(msg["message"]))
cloud

# %%
plt.imshow(cloud)

# %%
msg_ham=msg[msg.label=="ham"]
msg_ham
# Out:
#      label                                            message  length
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# 6      ham  Even my brother is not like to speak with me. ...      77
# ...    ...                                                ...     ...
# 6769   ham                                       Huh y lei...      12
# 6772   ham              Will Ì_ b going to esplanade fr home?      37
# 6773   ham  Pity, * was in mood for that. So...any other s...      57
# 6774   ham  The guy did some bitching but I acted like i'd...     125
# 6775   ham                         Rofl. Its true to its name      26
#
# [5854 rows x 3 columns]

# %%
wc=WordCloud(max_words=50)

# %%
cloud_ham=wc.generate(str(msg_ham.message))
cloud_ham

# %%
fig=plt.figure(figsize=(15,15))
plt.imshow(cloud_ham)

# %%
# cloud for spam

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer=CountVectorizer(analyzer=text_process).fit(msg["message"])
bow_transformer.vocabulary_
# Out:
# {'Go': 2078,
#  'jurong': 7633,
#  'point': 8986,
#  'crazy': 5863,
#  'Available': 1117,
#  'bugis': 5314,
#  'n': 8408,
#  'great': 7023,
#  'world': 11219,
#  'la': 7744,
#  'e': 6309,
#  'buffet': 5313,
#  'Cine': 1497,
#  'got': 6992,
#  'amore': 4754,
#  'wat': 11021,
#  'Ok': 3122,
#  'lar': 7777,
#  'Joking': 2489,
#  'wif': 11128,
#  'u': 10758,
#  'oni': 8659,
#  'Free': 1959,
#  'entry': 6422,
#  '2': 421,
#  'wkly': 11179,
#  'comp': 5713,
#  'win': 11140,
#  'FA': 1855,
#  'Cup': 1565,
#  'final': 6648,
#  'tkts': 10574,
#  '21st': 441,
#  'May': 2843,
#  '2005': 428,
#  'Text': 4015,
#  '87121': 858,
#  'receive': 9320,
#  'questionstd': 9227,
#  'txt': 10746,
#  'rateTCs': 9268,
#  'apply': 4832,
#  '08452810075over18s': 72,
#  'U': 4140,
#  'dun': 6296,
#  'say': 9621,
#  'early': 6314,
#  'hor': 7268,
#  'c': 5357,
#  'already': 4731,
#  'Nah': 2993,
#  'I': 2321,
#  'dont': 6216,
#  'think': 10496,
#  'goes': 6963,
#  'usf': 10857,
#  'lives': 7917,
#  'around': 4878,
#  'though': 10513,
#  'FreeMsg': 1961,
#  'Hey': 2249,
#  'darling': 5958,
#  '3': 534,
#  'weeks': 11067,
#  'word': 11206,
#  'back': 4994,
#  'Id': 2380,
#  'like': 7875,
#  'fun': 6845,
#  'still': 10158,
#  'Tb': 3993,
#  'ok': 8636,
#  'XxX': 4475,
#  'std': 10138,
#  'chgs': 5562,
#  'send': 9707,
#  'å£150': 11426,
#  'rcv': 9277,
#  'Even': 1824,
#  'brother': 5289,
#  'speak': 10036,
#  'They': 4043,
#  'treat': 10689,
#  'aids': 4692,
#  'patent': 8830,
#  'As': 1099,
#  'per': 8865,
#  'request': 9424,
#  'Melle': 2854,
#  'Oru': 3160,
#  'Minnaminunginte': 2873,
#  'Nurungu': 3071,
#  'Vettam': 4245,
#  'set': 9730,
#  'callertune': 5388,
#  'Callers': 1434,
#  'Press': 3336,
#  '9': 896,
#  'copy': 5810,
#  'friends': 6810,
#  'Callertune': 1435,
#  'WINNER': 4306,
#  'valued': 10884,
#  'network': 8478,
#  'customer': 5914,
#  'selected': 9694,
#  'receivea': 9321,
#  'å£900': 11467,
#  'prize': 9127,
#  'reward': 9481,
#  'To': 4080,
#  'claim': 5614,
#  'call': 5371,
#  '09061701461': 218,
#  'Claim': 1499,
#  'code': 5669,
#  'KL341': 2516,
#  'Valid': 4235,
#  '12': 324,
#  'hours': 7283,
#  'Had': 2193,
#  'mobile': 8288,
#  '11': 314,
#  'months': 8323,
#  'R': 3379,
#  'entitled': 6419,
#  'Update': 4202,
#  'latest': 7792,
#  'colour': 5689,
#  'mobiles': 8289,
#  'camera': 5400,
#  'Call': 1430,
#  'The': 4029,
#  'Mobile': 2892,
#  'Co': 1506,
#  'FREE': 1884,
#  '08002986030': 57,
#  'Im': 2387,
#  'gonna': 6976,
#  'home': 7242,
#  'soon': 9996,
#  'want': 11001,
#  'talk': 10367,
#  'stuff': 10217,
#  'anymore': 4802,
#  'tonight': 10618,
#  'k': 7638,
#  'Ive': 2433,
#  'cried': 5877,
#  'enough': 6410,
#  'today': 10586,
#  'SIX': 3550,
#  'chances': 5506,
#  'CASH': 1368,
#  'From': 1975,
#  '100': 293,
#  '20000': 425,
#  'pounds': 9044,
#  'CSH11': 1419,
#  '87575': 862,
#  'Cost': 1538,
#  '150pday': 362,
#  '6days': 750,
#  '16': 380,
#  'TsandCs': 4120,
#  'Reply': 3470,
#  'HL': 2162,
#  '4': 596,
#  'info': 7434,
#  'URGENT': 4162,
#  'You': 4539,
#  '1': 291,
#  'week': 11062,
#  'membership': 8183,
#  'å£100000': 11420,
#  'Prize': 3341,
#  'Jackpot': 2460,
#  'Txt': 4134,
#  'CLAIM': 1393,
#  'No': 3033,
#  '81010': 808,
#  'TC': 3907,
#  'wwwdbuknet': 11287,
#  'LCCLTD': 2587,
#  'POBOX': 3200,
#  '4403LDNW1A7RW18': 617,
#  'searching': 9663,
#  'right': 9490,
#  'words': 11210,
#  'thank': 10456,
#  'breather': 5263,
#  'promise': 9161,
#  'wont': 11201,
#  'take': 10359,
#  'help': 7172,
#  'granted': 7015,
#  'fulfil': 6841,
#  'wonderful': 11198,
#  'blessing': 5172,
#  'times': 10554,
#  'HAVE': 2139,
#  'A': 919,
#  'DATE': 1583,
#  'ON': 3092,
#  'SUNDAY': 3621,
#  'WITH': 4309,
#  'WILL': 4304,
#  'XXXMobileMovieClub': 4467,
#  'use': 10851,
#  'credit': 5868,
#  'click': 5635,
#  'WAP': 4275,
#  'link': 7893,
#  'next': 8491,
#  'message': 8206,
#  'httpwap': 7306,
#  'xxxmobilemovieclubcomnQJKGIGHJJGCBL': 11329,
#  'Oh': 3117,
#  'kim': 7695,
#  'watching': 11026,
#  'Eh': 1791,
#  'remember': 9387,
#  'spell': 10050,
#  'name': 8420,
#  'Yes': 4524,
#  'He': 2221,
#  'v': 10872,
#  'naughty': 8440,
#  'make': 8073,
#  'wet': 11096,
#  'Fine': 1931,
#  'thatåÕs': 10469,
#  'way': 11035,
#  'feel': 6608,
#  'ThatåÕs': 4027,
#  'gota': 6993,
#  'b': 4981,
#  'England': 1806,
#  'Macedonia': 2811,
#  'miss': 8263,
#  'goalsteam': 6956,
#  'news': 8486,
#  'ur': 10835,
#  'national': 8434,
#  'team': 10402,
#  '87077': 857,
#  'eg': 6350,
#  'ENGLAND': 1749,
#  'TryWALES': 4114,
#  'SCOTLAND': 3516,
#  '4txtÌ¼120': 665,
#  'POBOXox36504W45WQ': 3203,
#  'Is': 2420,
#  'seriously': 9724,
#  'I‰Û÷m': 2440,
#  'going': 6968,
#  'try': 10715,
#  'ha': 7076,
#  'joking': 7612,
#  'So': 3777,
#  'Ì': 11410,
#  'pay': 8838,
#  'first': 6675,
#  'Then': 4035,
#  'da': 5926,
#  'stock': 10162,
#  'comin': 5703,
#  'Aft': 1016,
#  'finish': 6661,
#  'lunch': 8020,
#  'go': 6950,
#  'str': 10182,
#  'lor': 7963,
#  'Ard': 1088,
#  'smth': 9946,
#  'Ffffffffff': 1922,
#  'Alright': 1053,
#  'meet': 8165,
#  'sooner': 9997,
#  'Just': 2505,
#  'forced': 6746,
#  'eat': 6326,
#  'slice': 9901,
#  'really': 9302,
#  'hungry': 7331,
#  'tho': 10509,
#  'This': 4052,
#  'sucks': 10250,
#  'Mark': 2833,
#  'getting': 6918,
#  'worried': 11225,
#  'knows': 7720,
#  'sick': 9829,
#  'turn': 10732,
#  'pizza': 8938,
#  'Lol': 2683,
#  'always': 4743,
#  'convincing': 5797,
#  'Did': 1679,
#  'catch': 5469,
#  'bus': 5333,
#  'Are': 1089,
#  'frying': 6831,
#  'egg': 6352,
#  'tea': 10396,
#  'eating': 6329,
#  'moms': 8307,
#  'left': 7823,
#  'dinner': 6139,
#  'Do': 1702,
#  'Love': 2696,
#  'amp': 4756,
#  'packing': 8762,
#  'car': 5427,
#  'Ill': 2385,
#  'let': 7844,
#  'know': 7716,
#  'theres': 10484,
#  'room': 9528,
#  'Ahhh': 1027,
#  'Work': 4443,
#  'vaguely': 10875,
#  'What': 4392,
#  'Wait': 4343,
#  'thats': 10468,
#  'clear': 5629,
#  'sure': 10301,
#  'sarcastic': 9603,
#  'x': 11316,
#  'doesnt': 6193,
#  'live': 7914,
#  'us': 10845,
#  'Yeah': 4515,
#  'apologetic': 4820,
#  'fallen': 6559,
#  'actin': 4611,
#  'spoilt': 10070,
#  'child': 5578,
#  'caught': 5473,
#  'Till': 4068,
#  'But': 1343,
#  'Not': 3059,
#  'badly': 4999,
#  'cheers': 5545,
#  'K': 2507,
#  'tell': 10418,
#  'anything': 4808,
#  'For': 1947,
#  'fear': 6600,
#  'fainting': 6550,
#  'housework': 7287,
#  'Quick': 3374,
#  'cuppa': 5904,
#  'Thanks': 4020,
#  'subscription': 10240,
#  'Ringtone': 3480,
#  'UK': 4145,
#  'charged': 5518,
#  'å£5month': 11459,
#  'Please': 3293,
#  'confirm': 5755,
#  'replying': 9419,
#  'YES': 4485,
#  'NO': 2969,
#  'If': 2384,
#  'reply': 9417,
#  'Yup': 4553,
#  'look': 7955,
#  'timings': 10560,
#  'msg': 8355,
#  'Xuhui': 4474,
#  'learn': 7812,
#  '2nd': 517,
#  'may': 8138,
#  'lesson': 7842,
#  '8am': 890,
#  'Oops': 3146,
#  'roommates': 9531,
#  'done': 6213,
#  'see': 9679,
#  'letter': 7846,
#  'B': 1126,
#  'Anything': 1074,
#  'decide': 6009,
#  'Hello': 2234,
#  'Hows': 2309,
#  'saturday': 9613,
#  'texting': 10447,
#  'youd': 11373,
#  'decided': 6010,
#  'tomo': 10607,
#  'im': 7387,
#  'trying': 10717,
#  'invite': 7490,
#  'Pls': 3295,
#  'ahead': 4684,
#  'watts': 11033,
#  'wanted': 11003,
#  'weekend': 11064,
#  'Abiola': 995,
#  'forget': 6752,
#  'need': 8458,
#  'crave': 5860,
#  'love': 7987,
#  'sweet': 10325,
#  'Arabian': 1086,
#  'steed': 10144,
#  'Mmmmmm': 2886,
#  'Yummy': 4550,
#  '07732584351': 29,
#  'Rodger': 3486,
#  'Burns': 1341,
#  'MSG': 2794,
#  'We': 4371,
#  'tried': 10698,
#  'sms': 9941,
#  'free': 6790,
#  'nokia': 8525,
#  'camcorder': 5398,
#  '08000930705': 53,
#  'delivery': 6044,
#  'tomorrow': 10610,
#  'WHO': 4298,
#  'ARE': 968,
#  'YOU': 4498,
#  'SEEING': 3519,
#  'Great': 2106,
#  'hope': 7260,
#  'man': 8082,
#  'well': 11079,
#  'endowed': 6394,
#  'ltgt': 8012,
#  'inches': 7413,
#  'callsmessagesmissed': 5394,
#  'calls': 5393,
#  'Didnt': 1680,
#  'get': 6910,
#  'hep': 7181,
#  'immunisation': 7395,
#  'nigeria': 8498,
#  'Fair': 1910,
#  'hopefully': 7264,
#  'tyler': 10752,
#  'cant': 5416,
#  'could': 5832,
#  'maybe': 8140,
#  'ask': 4900,
#  'bit': 5150,
#  'stubborn': 10208,
#  'didnt': 6108,
#  'even': 6460,
#  'hospital': 7274,
#  'kept': 7671,
#  'telling': 10419,
#  'weak': 11039,
#  'sucker': 10248,
#  'Hospitals': 2300,
#  'suckers': 10249,
#  'thinked': 10498,
#  'First': 1935,
#  'time': 10550,
#  'saw': 9620,
#  'class': 5622,
#  'gram': 7009,
#  'usually': 10863,
#  'runs': 9563,
#  'half': 7088,
#  'eighth': 6359,
#  'smarter': 9923,
#  'gets': 6914,
#  'almost': 4727,
#  'whole': 11119,
#  'second': 9667,
#  'fyi': 6858,
#  'ride': 9489,
#  'morning': 8328,
#  'hes': 7192,
#  'crashing': 5859,
#  'place': 8939,
#  'Wow': 4450,
#  'never': 8481,
#  'realized': 9300,
#  'embarassed': 6379,
#  'accomodations': 4594,
#  'thought': 10514,
#  'liked': 7876,
#  'since': 9853,
#  'best': 5111,
#  'seemed': 9685,
#  'happy': 7119,
#  'cave': 5477,
#  'sorry': 10006,
#  'give': 6936,
#  'offered': 8616,
#  'embarassing': 6380,
#  'SMS': 3561,
#  'ac': 4580,
#  'Sptv': 3820,
#  'New': 3013,
#  'Jersey': 2479,
#  'Devils': 1673,
#  'Detroit': 1672,
#  'Red': 3450,
#  'Wings': 4419,
#  'play': 8953,
#  'Ice': 2378,
#  'Hockey': 2278,
#  'Correct': 1536,
#  'Incorrect': 2396,
#  'End': 1804,
#  'END': 1747,
#  'SPTV': 3592,
#  'Mallika': 2823,
#  'Sherawat': 3708,
#  'yesterday': 11354,
#  'Find': 1930,
#  'ltURLgt': 8011,
#  'Congrats': 1527,
#  'year': 11345,
#  'special': 10038,
#  'cinema': 5610,
#  'pass': 8819,
#  '09061209465': 213,
#  'C': 1351,
#  'Suprman': 3880,
#  'V': 4219,
#  'Matrix3': 2840,
#  'StarWars3': 3829,
#  'etc': 6450,
#  'bx420ip45we': 5352,
#  '150pm': 363,
#  'Dont': 1715,
#  'Sorry': 3793,
#  'later': 7790,
#  'meeting': 8167,
#  'Tell': 4004,
#  'reached': 9284,
#  'Yesgauti': 4527,
#  'sehwag': 9691,
#  'odi': 8611,
#  'series': 9722,
#  'Your': 4543,
#  'pick': 8913,
#  'burger': 5325,
#  'move': 8342,
#  'Pain': 3238,
#  'killing': 7692,
#  'Ha': 2190,
#  'good': 6978,
#  'joke': 7607,
#  'Girls': 2073,
#  'situation': 9873,
#  'seekers': 9682,
#  'Its': 2428,
#  'part': 8808,
#  'checking': 5542,
#  'IQ': 2361,
#  'took': 10626,
#  'forever': 6749,
#  'come': 5696,
#  'double': 6227,
#  'check': 5539,
#  'hair': 7085,
#  'dresser': 6254,
#  'said': 9579,
#  'wun': 11264,
#  'cut': 5917,
#  'short': 9795,
#  'nice': 8494,
#  'pleased': 8964,
#  'advise': 4649,
#  'following': 6730,
#  'recent': 9324,
#  'review': 9479,
#  'Mob': 2889,
#  'awarded': 4974,
#  'å£1500': 11427,
#  'Bonus': 1293,
#  '09066364589': 262,
#  'Today': 4082,
#  'song': 9992,
#  'dedicated': 6019,
#  'day': 5975,
#  'Which': 4406,
#  'dedicate': 6018,
#  'Send': 3677,
#  'valuable': 10881,
#  'frnds': 6819,
#  'rply': 9544,
#  'Urgent': 4209,
#  'UR': 4159,
#  'complimentary': 5730,
#  'trip': 10699,
#  'EuroDisinc': 1821,
#  'Trav': 4104,
#  'AcoEntry41': 1005,
#  'Or': 3152,
#  'å£1000': 11418,
#  'DIS': 1603,
#  '186å£150moreFrmMob': 389,
#  'ShrAcomOrSglSuplt10': 3729,
#  'LS1': 2624,
#  '3AJ': 567,
#  'hear': 7149,
#  'new': 8484,
#  'Divorce': 1696,
#  'Barbie': 1232,
#  'It': 2424,
#  'comes': 5700,
#  'Kens': 2534,
#  'plane': 8946,
#  'month': 8320,
#  'end': 6390,
#  'Wah': 4341,
#  'lucky': 8017,
#  'save': 9616,
#  'money': 8313,
#  'Hee': 2229,
#  'Finished': 1934,
#  'HI': 2156,
#  'BABE': 1130,
#  'IM': 2339,
#  'AT': 978,
#  'HOME': 2168,
#  'NOW': 2982,
#  'WANNA': 4272,
#  'DO': 1606,
#  'SOMETHING': 3570,
#  'XX': 4464,
#  'Kkwhere': 2564,
#  'youhow': 11376,
#  'performed': 8872,
#  'waiting': 10980,
#  'machan': 8042,
#  'Thats': 4026,
#  'cool': 5803,
#  'gentleman': 6904,
#  'dignity': 6130,
#  'respect': 9445,
#  'peoples': 8864,
#  'much': 8371,
#  'shy': 9825,
#  'pa': 8757,
#  'Does': 1705,
#  'operate': 8675,
#  'Still': 3841,
#  'looking': 7958,
#  'job': 7594,
#  'How': 2306,
#  'Tas': 3990,
#  'earn': 6315,
#  'ah': 4682,
#  'hi': 7199,
#  'stop': 10171,
#  'urgnt': 10840,
#  'real': 9294,
#  'yo': 11363,
#  'tickets': 10541,
#  'one': 8655,
#  'jacket': 7555,
#  'used': 10852,
#  'multis': 8379,
#  'started': 10119,
#  'requests': 9425,
#  'pain': 8769,
#  'came': 5399,
#  'bed': 5072,
#  'Double': 1721,
#  'coins': 5675,
#  'factory': 6542,
#  'gotta': 6996,
#  'cash': 5458,
#  'nitros': 8515,
#  'babe': 4986,
#  'Ela': 1794,
#  'kanoil': 7654,
#  'download': 6233,
#  'wen': 11084,
#  'Don‰Û÷t': 1718,
#  'stand': 10108,
#  'close': 5641,
#  'you‰Û÷ll': 11393,
#  'something': 9980,
#  'another': 4787,
#  'night': 8499,
#  'spent': 10055,
#  'late': 7785,
#  'afternoon': 4665,
#  'casualty': 5467,
#  'means': 8156,
#  'havent': 7134,
#  'stuff42moro': 10218,
#  'includes': 7416,
#  'sheets': 9765,
#  'Smile': 3769,
#  'Pleasure': 3294,
#  'trouble': 10704,
#  'pours': 9046,
#  'Rain': 3423,
#  'sum1': 10268,
#  'Hurts': 2319,
#  'becoz': 5070,
#  'SOMEONE': 3568,
#  'Loves': 2702,
#  'Smiling': 3771,
#  'service': 9727,
#  'representative': 9422,
#  '0800': 49,
#  '169': 382,
#  '6031': 713,
#  '10am9pm': 308,
#  'WON': 4318,
#  'guaranteed': 7054,
#  'å£5000': 11454,
#  'Havent': 2218,
#  'planning': 8950,
#  'buy': 5344,
#  'lido': 7858,
#  '530': 684,
#  'show': 9809,
#  'work': 11211,
#  'ringtone': 9497,
#  'collected': 5682,
#  'Simply': 3739,
#  'text': 10442,
#  'password': 8827,
#  'MIX': 2769,
#  '85069': 843,
#  'verify': 10902,
#  'Get': 2065,
#  'Usher': 4214,
#  'Britney': 1327,
#  'FML': 1878,
#  'Watching': 4365,
#  'telugu': 10423,
#  'moviewat': 8347,
#  'abt': 4576,
#  'When': 4397,
#  'loads': 7925,
#  'loans': 7927,
#  'Hi': 2252,
#  'Wk': 4428,
#  'hols': 7240,
#  'run': 9560,
#  'Forgot': 1952,
#  'hairdressers': 7087,
#  'appointment': 4836,
#  'four': 6776,
#  'shower': 9811,
#  'beforehand': 5082,
#  'cause': 5474,
#  'prob': 9131,
#  'ham': 7092,
#  'nothing': 8550,
#  'else': 6374,
#  'Okay': 3123,
#  'price': 9107,
#  'long': 7951,
#  'legal': 7826,
#  'Wen': 4383,
#  'Y': 4477,
#  'ave': 4962,
#  'ams': 4758,
#  'xx': 11326,
#  'And': 1069,
#  'gone': 6974,
#  '4the': 663,
#  'driving': 6263,
#  'test': 10438,
#  'yet': 11355,
#  'wow': 11240,
#  'Youre': 4544,
#  'mean': 8152,
#  'guess': 7058,
#  'gave': 6887,
#  'boston': 5223,
#  'men': 8188,
#  'changed': 5508,
#  'search': 9662,
#  'location': 7930,
#  'nyc': 8589,
#  'Cuz': 1574,
#  'signin': 9839,
#  'page': 8765,
#  'says': 9625,
#  'Umma': 4181,
#  'life': 7861,
#  'vava': 10892,
#  'umma': 10771,
#  'lot': 7972,
#  'dear': 5996,
#  'wishes': 11160,
#  'birthday': 5148,
#  'making': 8077,
#  'truly': 10711,
#  'memorable': 8185,
#  'Aight': 1030,
#  'hit': 7218,
#  'would': 11236,
#  'ip': 7498,
#  'address': 4626,
#  'considering': 5772,
#  'computer': 5736,
#  'isnt': 7520,
#  'minecraft': 8242,
#  'server': 9726,
#  'Grumpy': 2110,
#  'old': 8649,
#  'people': 8863,
#  'My': 2942,
#  'mom': 8304,
#  'better': 5117,
#  'lying': 8033,
#  'jokes': 7609,
#  'worry': 11227,
#  'busy': 5339,
#  'plural': 8974,
#  'noun': 8557,
#  'research': 9431,
#  'Going': 2084,
#  'dinnermsg': 6140,
#  'cos': 5821,
#  'things': 10495,
#  'scared': 9631,
#  'mah': 8063,
#  'Cos': 1537,
#  'loud': 7982,
#  'GENT': 1998,
#  'contact': 5777,
#  'Last': 2642,
#  'weekends': 11065,
#  'draw': 6243,
#  'shows': 9816,
#  'GUARANTEED': 2040,
#  '09064012160': 237,
#  'Code': 1508,
#  'K52': 2508,
#  '12hrs': 336,
#  '150ppm': 368,
#  'Wa': 4339,
#  'openin': 8672,
#  'sentence': 9716,
#  'formal': 6760,
#  'Anyway': 1076,
#  'fine': 6656,
#  'juz': 7637,
#  'tt': 10721,
#  'eatin': 6328,
#  'puttin': 9211,
#  'weightHaha': 11072,
#  'anythin': 4807,
#  'happened': 7111,
#  'entered': 6412,
#  'cabin': 5359,
#  'PA': 3170,
#  'Happy': 2208,
#  'Bday': 1239,
#  'Boss': 1301,
#  'felt': 6617,
#  'She': 3706,
#  'askd': 4901,
#  'After': 1017,
#  'invited': 7491,
#  'apartment': 4816,
#  'went': 11086,
#  'winner': 11150,
#  'specially': 10042,
#  'holiday': 7236,
#  'flights': 6700,
#  'inc': 7411,
#  'operator': 8676,
#  '0871277810910pmin': 122,
#  '18': 385,
#  'Goodo': 2093,
#  'must': 8396,
#  'friday': 6803,
#  'eggpotato': 6353,
#  'ratio': 9271,
#  'tortilla': 10643,
#  'needed': 8460,
#  'Hmmmy': 2275,
#  'uncle': 10776,
#  'informed': 7438,
#  'paying': 8842,
#  'school': 9637,
#  'directly': 6144,
#  'pls': 8970,
#  'food': 6736,
#  'PRIVATE': 3225,
#  '2004': 427,
#  'Account': 1001,
#  'Statement': 3834,
#  '07742676969': 31,
#  '786': 775,
#  'unredeemed': 10814,
#  'Points': 3309,
#  '08719180248': 170,
#  'Identifier': 2382,
#  '45239': 629,
#  'Expires': 1847,
#  'å£2000': 11439,
#  'Caller': 1433,
#  '5903': 689,
#  'Landline': 2637,
#  '09064019788': 243,
#  'BOX42WR29C': 1192,
#  '150PPM': 353,
#  'applespairsall': 4830,
#  'malarky': 8079,
#  'Todays': 4083,
#  'Voda': 4254,
#  'numbers': 8580,
#  'ending': 6392,
#  '7548': 770,
#  '350': 557,
#  'award': 4973,
#  'match': 8119,
#  'please': 8963,
#  '08712300220': 104,
#  'quoting': 9238,
#  '4041': 601,
#  'standard': 10109,
#  'rates': 9269,
#  'app': 4824,
#  'sao': 9598,
#  'mu': 8370,
#  'Will': 4416,
#  'ÌÏ': 11413,
#  'predict': 9074,
#  'Ìll': 11411,
#  'buying': 5347,
#  'Good': 2088,
#  'knowyetunde': 7723,
#  'hasnt': 7126,
#  'sent': 9715,
#  'bother': 5225,
#  'sending': 9708,
#  'involve': 7495,
#  'shouldnt': 9803,
#  'imposed': 7401,
#  'apologise': 4821,
#  'HEY': 2152,
#  'GIRL': 2004,
#  'HOW': 2178,
#  'HOPE': 2171,
#  'WELL': 4283,
#  'ME': 2743,
#  'AN': 957,
#  'DEL': 1595,
#  'BAK': 1139,
#  'AGAIN': 936,
#  'LONG': 2611,
#  'TIME': 3949,
#  'GIVE': 2007,
#  'CALL': 1355,
#  'SUM': 3618,
#  'FROM': 1899,
#  'LUCYxx': 2630,
#  'Kkhow': 2558,
#  'cost': 5823,
#  'Dear': 1650,
#  'Tmorrowpls': 4075,
#  'accomodate': 4593,
#  'answer': 4790,
#  'question': 9224,
#  'Sunshine': 3876,
#  'Quiz': 3376,
#  'Wkly': 4429,
#  'Q': 3362,
#  'Win': 4417,
#  'top': 10634,
#  'Sony': 3790,
#  'DVD': 1631,
#  'player': 8955,
#  'country': 5838,
#  'Algarve': 1046,
#  'ansr': 4789,
#  '82277': 814,
#  'SPTyrone': 3593,
#  'Want': 4354,
#  'laid': 7757,
#  'Dogging': 1707,
#  'locations': 7931,
#  'direct': 6143,
#  'mob': 8287,
#  'Join': 2485,
#  'UKs': 4148,
#  'largest': 7779,
#  'Network': 3008,
#  'bt': 5303,
#  'Txting': 4137,
#  'GRAVEL': 2036,
#  '69888': 739,
#  'Nt': 3068,
#  'ec2a': 6331,
#  '31pmsg150p': 550,
#  'haf': 7081,
#  'msn': 8365,
#  'yijuehotmailcom': 11361,
#  'rooms': 9532,
#  ...}

# %%
len(bow_transformer.vocabulary_)
# Out:
# 11480

# %%
message_bow=bow_transformer.transform(msg.message)

# %%
type(message_bow)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
#message_bow.shape

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
Tfidf_Transformer=TfidfTransformer()

# %%
Tfidf_Transformer.fit(message_bow)
# Out:
# TfidfTransformer()

# %%
tfidf_mess=Tfidf_Transformer.transform(message_bow)
tfidf_mess
# Out:
# <6776x11480 sparse matrix of type '<class 'numpy.float64'>'
# 	with 67681 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
spam_np=nb.fit(tfidf_mess,msg["label"])
spam_np
# Out:
# MultinomialNB()

# %%
p_spam=spam_np.predict(tfidf_mess)
p_spam
# Out:
# array(['ham', 'ham', 'spam', ..., 'ham', 'ham', 'ham'], dtype='<U4')

# %%
from sklearn.metrics import confusion_matrix
from  sklearn.metrics import classification_report

# %%
cf1=confusion_matrix(p_spam,msg["label"])
cf1
# Out:
# array([[5854,   95],
#        [   0,  827]], dtype=int64)

# %%
ac=cf1.diagonal().sum()/cf1.sum()*100
ac
# Out:
# 98.59799291617473

# %%
print(classification_report(p_spam,msg["label"]))
# Out:
#               precision    recall  f1-score   support
#
#          ham       1.00      0.98      0.99      5949
#         spam       0.90      1.00      0.95       827
#
#     accuracy                           0.99      6776
#    macro avg       0.95      0.99      0.97      6776
# weighted avg       0.99      0.99      0.99      6776

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(tfidf_mess,msg["label"])
# Out:
# RandomForestClassifier()

# %%
rf_p=rf.predict(tfidf_mess)
rf_p
# Out:
# array(['ham', 'ham', 'spam', ..., 'ham', 'ham', 'ham'], dtype=object)

# %%
rf_cf=confusion_matrix(p_spam,msg["label"])
rf_cf
# Out:
# array([[5854,   95],
#        [   0,  827]], dtype=int64)

# %%
rf_acc=rf_cf.diagonal().sum()/rf_cf.sum()*100
rf_acc
# Out:
# 98.59799291617473

# %%
print(classification_report(p_spam,msg["label"]))
# Out:
#               precision    recall  f1-score   support
#
#          ham       1.00      0.98      0.99      5949
#         spam       0.90      1.00      0.95       827
#
#     accuracy                           0.99      6776
#    macro avg       0.95      0.99      0.97      6776
# weighted avg       0.99      0.99      0.99      6776
